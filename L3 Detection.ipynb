# %% [markdown]
# # L3 Slice detection
#
#
# This iPython notebook is designed to be ran in Google Colab, which meets the dectection alogirthms requirements (Linux with a GPU accelerator material).
#
#
#
# ##### Last update: April 25, 2021

# %% [markdown]
# ## Setting up the **environment**
#
# The first steps will require manual updating to make sure your drive is connected and the working directory is pointed to the correct location.
#
# The third step should run efficently without user interaction.

# %% [markdown]
# #### Step 1:
# Mount your google drive.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #### Step 2
# Set your directory path to the google drive location where you have downloaded the pre-requistes.

# %%
# %cd /content/gdrive/MyDrive/L3-Clean/
# Out:
# /content/gdrive/MyDrive/L3-Clean

# %% [markdown]
# #### Step 3
# Complete set-up of the enviorment.
#
# *Note: Comment out %%capture to see full output*

# %%
# %%capture
import os

#Download and activate conda 
if not os.path.exists("Anaconda3-5.2.0-Linux-x86_64.sh"):
  # !wget https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh

# !bash Anaconda3-5.2.0-Linux-x86_64.sh -bfp /usr/local

#Creating the python 3.6.2 environment for the project.
# !conda create -y --name sarcopenia-ai python=3.6.2 

# Activate newly created pthon environment
# !source create sarcopenia-ai

#Install packages for the enviroment
# %cd ./Setup 
# !/usr/local/envs/sarcopenia-ai/bin/pip install -e .
# %cd ..

# %% [markdown]
# ## L3 Detection
#
# Utilizing the eviroment built during setup, analyze collections of data CT images.
#
# **Input information**.
#
# -  -i : Name of the folder containing the images you would like to process.
#   - The contents of this folder should be structured in standard DICOM format (Patient - Study - Series).
#   - Image should be converted to an nii.gz format prior to analysis. This can be done utilizing the data prep code included in the github package.
#     - If the images have not been processed through data prep, please ensure that the data is stored in the NII_Data subfolder, rather than the data folder.
#
# - test_name: Name that you want to assign for the iteration of dectection.
#   - This can be utilized to differentiate between detection runs, where parameters may differ.
#
#
# *Note: Inputs should be folder name only. Please do not include full path name or '/' as the code automatically detects this information based off your folder structure*

# %%
# !/usr/local/envs/sarcopenia-ai/bin/python detection.py  -i 'ValidationSet' -test_name 'initial'
# Out:
# /usr/local/envs/sarcopenia-ai/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/envs/sarcopenia-ai/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/envs/sarcopenia-ai/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
